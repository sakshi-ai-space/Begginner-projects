# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
data = {
    "text": [
        "Win a free iPhone now!!!",
        "Are we still meeting tomorrow?",
        "Congratulations, you won a lottery prize!",
        "Let's have lunch today",
        "Urgent! Verify your account immediately"
    ],
    "label": ["spam", "ham", "spam", "ham", "spam"]
}
df= pd.DataFrame(data)
X_train,X_test,Y_train,Y_test=train_test_split(df["text"],df["label"],random_state=42,test_size=0.2)
vectorizer=TfidfVectorizer()
x_train_vect=vectorizer.fit_transform(X_train)
x_test_vect=vectorizer.transform(X_test)
model = MultinomialNB()
model.fit(x_train_vect, y_train)
pred=model.predict(x_test_vect)
print("accuracy", accuracy_score(Y_test,pred))

# Predict new email
new_email = ["Get free money now!!!"]
new_vect = vectorizer.transform(new_email)
print("Prediction:", model.predict(new_vect))
# Out:
# accuracy 0.0
# Prediction: ['spam']
